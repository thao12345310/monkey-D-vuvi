# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_with_nearest_restaurants.csv')
df.head()
# Out:
#    hotel_id                 hotel_name  total_rooms  \
# 0         1  DeLaSea Phát Linh Hạ Long          326
# 1         2   Citadines Marina Hạ Long          580
# 2         3    Sea Stars Hotel Hạ Long          354
# 3         4     Wyndham Legend Hạ Long          450
# 4         5        Hạ Long Dream Hotel          186
#
#                                          admin  hotel_price     city  \
# 0            CÔNG TY CỔ PHẦN ĐẦU TƯ TÂN HOA LƯ      1950000  Hạ Long
# 1                           The Ascott Limited      2000000  Hạ Long
# 2                              Sea Stars Group      2700000  Hạ Long
# 3  CÔNG TY CỔ PHẦN DU LỊCH DỊCH VỤ SAO HẠ LONG      2500000  Hạ Long
# 4                              Geleximco Group      1500000  Hạ Long
#
#                                              address  \
# 0  Lô 1, Đại Lộ Hạ Long Marine, Phường Bãi Cháy, ...
# 1      Bán đảo 3, Marina Halong, Hạ Long, Quảng Ninh
# 2  Lô N8-1/Số 47 Cái Dăm, Khu đô thị, Thành phố H...
# ...

# %%
df['link_web'] = "http://localhost/khach-san/" + df['hotel_id'].astype(str)
df
# Out:
#      hotel_id                               hotel_name  total_rooms  \
# 0           1                DeLaSea Phát Linh Hạ Long          326
# 1           2                 Citadines Marina Hạ Long          580
# 2           3                  Sea Stars Hotel Hạ Long          354
# 3           4                   Wyndham Legend Hạ Long          450
# 4           5                      Hạ Long Dream Hotel          186
# ..        ...                                      ...          ...
# 214       215                Melia Vinpearl Hotel Huế           213
# 215       216                Mường Thanh Grand Gia Lai          160
# 216       217          Golden Boutique Hotel Măng Đen            62
# 217       218               Stella Maris Beach Đà Nẵng           97
# 218       219  Đà Nẵng Mikazuki Japanese Resorts & Spa          294
#
#                                            admin  hotel_price  \
# 0              CÔNG TY CỔ PHẦN ĐẦU TƯ TÂN HOA LƯ      1950000
# ...

# %%
df2= pd.read_csv('ship.csv')
df2
# Out:
#     ship_id                              ship_name  launch  cabin     shell  \
# 0         1  Du thuyền Heritage  Bình Chuẩn Cát Bà    2019     20  Kim loại
# 1         2                    Du thuyền Indochine    2019     43  Kim loại
# 2         3                   Du thuyền Le Theatre    2019     21  Kim loại
# 3         4                Du thuyền Orchid Trendy    2017     20  Kim loại
# 4         5                      Du thuyền Milalux    2012     20  Kim loại
# ..      ...                                    ...     ...    ...       ...
# 66       67                Du thuyền Lyra Grandeur    2025     33  Kim Loại
# 67       68              Du thuyền Indochine Grand    2025     32  Kim loại
# 68       69              Du thuyền Calista Hạ Long    2025     38  Kim loại
# 69       70         Du thuyền Majesty Prime Cruise    2024     24  Kim loại
# 70       71       Du thuyền Verdure Lotus Grandeur    2025     22  Kim loại
#
#                                                  trip  \
# ...

# %%
df.to_csv('hotel_with_nearest_restaurants.csv', index=False)

# %%
df2['link_web'] = "http://localhost/du-thuyen/" + df2['ship_id'].astype(str)
df2.head()
# Out:
#    ship_id                              ship_name  launch  cabin     shell  \
# 0        1  Du thuyền Heritage  Bình Chuẩn Cát Bà    2019     20  Kim loại
# 1        2                    Du thuyền Indochine    2019     43  Kim loại
# 2        3                   Du thuyền Le Theatre    2019     21  Kim loại
# 3        4                Du thuyền Orchid Trendy    2017     20  Kim loại
# 4        5                      Du thuyền Milalux    2012     20  Kim loại
#
#                                                 trip  \
# 0  Vịnh Lan Hạ - Bãi tắm Ba Trái Đào  - Hang Sáng...
# 1   Vịnh Lan Hạ - Làng chài Việt Hải – Hang Sáng Tối
# 2  Vịnh Lan Hạ - Làng Việt Hải – Hang Sáng Tối – ...
# 3    Vịnh Lan Hạ - Hang Trung Trang – Khu vực Ao Ếch
# 4  Vịnh Hạ Long – Khu vực Tùng Sâu – Đảo Titop – ...
#
#                                        admin  ship_price  \
# 0           Công ty cổ phần Heritage Cruises     4150000
# 1                 Tập đoàn du lịch Hương Hải     4125000
# ...

# %%
df2.to_csv('ship.csv', index=False)
