# %%
import pandas as pd

# %%
from dotenv import load_dotenv
import os 
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA
load_dotenv('.env')
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-4o")
model.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 14, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BanDUIEAeqKT7XlvjYVlkSGfUaKis', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a2d930c4-c5cc-4d38-bfef-e46f499e8b5f-0', usage_metadata={'input_tokens': 14, 'output_tokens': 7, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Qdrant implementation

# %%
csv_file = "data/hotel_with_nearest_restaurants.csv"
df = pd.read_csv(csv_file)
df
# Out:
#      hotel_id                               hotel_name  total_rooms  \
# 0           1                DeLaSea Phát Linh Hạ Long          326
# 1           2                 Citadines Marina Hạ Long          580
# 2           3                  Sea Stars Hotel Hạ Long          354
# 3           4                   Wyndham Legend Hạ Long          450
# 4           5                      Hạ Long Dream Hotel          186
# ..        ...                                      ...          ...
# 214       215                Melia Vinpearl Hotel Huế           213
# 215       216                Mường Thanh Grand Gia Lai          160
# 216       217          Golden Boutique Hotel Măng Đen            62
# 217       218               Stella Maris Beach Đà Nẵng           97
# 218       219  Đà Nẵng Mikazuki Japanese Resorts & Spa          294
#
#                                            admin  hotel_price  \
# 0              CÔNG TY CỔ PHẦN ĐẦU TƯ TÂN HOA LƯ      1950000
# 1                             The Ascott Limited      2000000
# 2                                Sea Stars Group      2700000
# 3    CÔNG TY CỔ PHẦN DU LỊCH DỊCH VỤ SAO HẠ LONG      2500000
# 4                                Geleximco Group      1500000
# ..                                           ...          ...
# 214                    Melia Vinpearl Hotel Huế       2500000
# 215                    Mường Thanh Grand Gia Lai      1500000
# 216              Golden Boutique Hotel Măng Đen       2300000
# 217                   Stella Maris Beach Đà Nẵng      1500000
# 218      Đà Nẵng Mikazuki Japanese Resorts & Spa      2500000
#
#                   city                                            address  \
# 0              Hạ Long  Lô 1, Đại Lộ Hạ Long Marine, Phường Bãi Cháy, ...
# 1              Hạ Long      Bán đảo 3, Marina Halong, Hạ Long, Quảng Ninh
# 2              Hạ Long  Lô N8-1/Số 47 Cái Dăm, Khu đô thị, Thành phố H...
# 3              Hạ Long  12 Hạ Long, Bãi Cháy, Thành phố Hạ Long, Quảng...
# 4              Hạ Long  số 10 đường Hạ Long, phường Bãi Cháy, Tp. Hạ Long
# ..                 ...                                                ...
# 214     Thừa Thiên Huế  50A, đường Hùng Vương, TP.Huế, tỉnh Thừa Thiên...
# 215            Gia Lai   537 Hùng Vương, Phường Phù Đổng, Thành phố Pl...
# 216            Kon Tum  Lô biệt thự số 26 Nguyễn Du, Thị Trấn Măng Đen...
# 217  Bà Rịa - Vũng Tàu   03 Võ Văn Kiệt, Phường Phước Mỹ, Quận Sơn Trà...
# 218            Đà Nẵng  Khu du lịch Xuân Thiều, Đường Nguyễn Tất Thành...
#
#                                       map_link  \
# 0    https://maps.app.goo.gl/yxDCjgQvorHL43xX9
# 1    https://maps.app.goo.gl/yseMCyJmvGiZ1t7v9
# 2    https://maps.app.goo.gl/8EyutG7DHVyU4Xf88
# 3    https://maps.app.goo.gl/A5ueMVJi4M7CXhJG7
# 4    https://maps.app.goo.gl/EMV8uhrwSEetkPX17
# ..                                         ...
# 214  https://maps.app.goo.gl/N47jGfG8f3ehgj7V9
# 215  https://maps.app.goo.gl/BpN9cYfvMQXvWrCTA
# 216  https://maps.app.goo.gl/4FYFbig8uhjF539HA
# 217  https://maps.app.goo.gl/KMJ4EwRrARtaToPMA
# 218  https://maps.app.goo.gl/AtsAtyhDGZEGJ3vH6
#
#                                         hotel_features  \
# 0    Phòng có bồn tắm, Lễ tân 24h, Wifi miễn phí, N...
# 1    Wifi miễn phí, Lễ tân 24h, Bể bơi ngoài trời, ...
# 2    Bể bơi ngoài trời, Wifi miễn phí, Ban công/Cửa...
# 3    Phòng có bồn tắm, Lễ tân 24h, Wifi miễn phí, B...
# 4    Phòng có bồn tắm, Lễ tân 24h, Wifi miễn phí, N...
# ..                                                 ...
# 214  Wifi miễn phí, Phòng có bồn tắm, Nhà hàng, Lễ ...
# 215  Wifi miễn phí, Phòng có bồn tắm, Nhà hàng, Lễ ...
# 216  Bể bơi ngoài trời, Phòng có bồn tắm, Wifi miễn...
# 217  Bể bơi ngoài trời, Wifi miễn phí, Phòng có bồn...
# 218  Bể bơi ngoài trời, Wifi miễn phí, Phòng có bồn...
#
#                                      short_description  \
# 0    Với tông màu chủ đạo vàng, trắng sử dụng trong...
# 1    Sở hữu vị trí trung tâm và tọa lạc ngay gần co...
# 2    Tại Sea Stars, chúng tôi cung cấp đầy đủ những...
# 3    Nhà hàng Blue Bay không chỉ nổi bật với thực đ...
# 4    Các phòng nghỉ với phong cách thiết kế mới mẻ,...
# ..                                                 ...
# 214  Bể bơi bốn mùa. Hệ thống nhà hàng và bar: Nhà ...
# 215  Tọa lạc ngay trung tâm thành phố Pleiku Các ph...
# 216  Tọa lạc giữa trung tâm cao nguyên Măng Đen Hồ ...
# 217  Nằm cách bãi biển Mỹ Khê chỉ 50m Hồ bơi trên t...
# 218  Đắm mình trong văn hóa Nhật Bản và dịch vụ Ryo...
#
#                                       long_description   latitude   longitude  \
# 0    Khách sạn 5 sao Phát Linh tọa lạc tại đại lộ M...  20.955721  106.935051
# 1    Citadines Marina Halong toạ lạc tại tổ hợp du ...  20.953638  106.930797
# 2    Sea Stars Hotel Hạ Long tự hào là khách sạn 5 ...  20.948831  106.941587
# 3    Wyndham Legend Hạ Long là khách sạn 5 sao đầu ...  20.959447  106.977972
# 4    Khách sạn Ha Long Dream là một trong những khá...  20.956582  106.967884
# ..                                                 ...        ...         ...
# 214  Melia Vinpearl Hotel Huế - nơi truyền thống th...  16.463047  107.591816
# 215  Mường Thanh Grand Gia Lai Hotel, khách sạn 4 s...  13.972530  108.011678
# 216  Golden Boutique Hotel Măng Đen Kon Tum&nbsp;tọ...  14.585493  108.278374
# 217  Khách sạn Stella Maris Beach Đà Nẵng được thiế...  16.063502  108.242324
# 218  Đà Nẵng Mikazuki Japanese Resorts &amp; Spa th...  16.093429  108.141812
#
#                                    nearest_restaurants  \
# 0    Nhà hàng: Ăn Đêm Đồ Nhậu, Địa chỉ: Quốc Lộ 18 ...
# 1    Nhà hàng: Ăn Đêm Đồ Nhậu, Địa chỉ: Quốc Lộ 18 ...
# 2    Nhà hàng: Nhà Hàng Quỳnh Ngọc, Địa chỉ: 574,Qu...
# 3    Nhà hàng: Nhà Hàng Vân Anh, Địa chỉ: Quốc Lộ 1...
# 4    Nhà hàng: Nhà Hàng Quỳnh Ngọc, Địa chỉ: 574,Qu...
# ..                                                 ...
# 214  Nhà hàng: Vuon Pho Restaurant, Địa chỉ: 6A Ly ...
# 215  Nhà hàng: Quán Nhậu Hai Cảng, Địa chỉ: 1 Nguyễ...
# 216  Nhà hàng: Gà Nướng Cơm Lam Cô Sinh ( Chính H...
# 217  Nhà hàng: MAMA HOT POT Buffet - Võ Văn Kiệt, Đ...
# 218  Nhà hàng: Cơm Gà Gia Vĩnh, Địa chỉ: 129 Lý Tự ...
#
#                            link_web
# 0      http://localhost/khach-san/1
# 1      http://localhost/khach-san/2
# 2      http://localhost/khach-san/3
# 3      http://localhost/khach-san/4
# 4      http://localhost/khach-san/5
# ..                              ...
# 214  http://localhost/khach-san/215
# 215  http://localhost/khach-san/216
# 216  http://localhost/khach-san/217
# 217  http://localhost/khach-san/218
# 218  http://localhost/khach-san/219
#
# [219 rows x 15 columns]

# %%
from langchain.schema import Document

doc = []
ship_file = "data/ship.csv"
df3 = pd.read_csv(ship_file)
for idx, row in df3.iterrows():
    doc.append(Document(page_content=f"Tàu {row['ship_name']} có link trên web MonkeyDvuvi là {row['link_web']}, có số cabin là {row['cabin']}, trip đi {row['trip']} bởi công ty {row['admin']}, giá thành là {row['ship_price']}, địa chỉ ở {row['address']} với link map {row['map_link']}. Thuyền gồm các tiện ích sau {row['ship_features']}, {row['long_description']}\n", metadata={"type": "ship"}))
    
room_ship_file = "data/ship_rooms.csv"
df4 = pd.read_csv(room_ship_file)
df4 = df4.merge(df3[['ship_id', 'ship_name']], on='ship_id', how='left')

for idx, row in df4.iterrows():
    doc.append(Document(page_content=f"Tàu {row['ship_id']} có phòng loại {row['room_name']}, có kích thước {row['size']}m2, chứa được {row['max_persons']}. Giá phòng là {row['room_price']} và có các đặc trưng sau {row['room_features']}\n", metadata={"type": "ship_room", "ship_name": row['ship_name']}))
for idx, row in df.iterrows():
    doc.append(Document(page_content=f"Khách sạn {row['hotel_name']} có link trên web MonkeyDvuvi là {row['link_web']} với tổng cộng {row['total_rooms']} phòng, được quản lý bởi {row['admin']}, có giá {row['hotel_price']} đồng, nằm tại {row['city']}, địa chỉ {row['address']}, với đường dẫn bản đồ {row['map_link']}, có các tiện ích {row['hotel_features']}, và có các nhà hàng gần nhất:\n{row['nearest_restaurants']}, mô tả ngắn gọn: {row['short_description']}, mô tả chi tiết: {row['long_description']} \n", metadata={"city": row['city'], "type": "hotel"}))
df2 = pd.read_csv("data/restaurant_final.csv")
for idx, row in df2.iterrows():
    doc.append(Document(page_content=f"Nhà hàng {row['name']} có địa chỉ {row['address']} với link Map {row['map_link']} có đánh giá {row['rating']}, giờ mở cửa là {row['open_hours']}, website {row['website']}, và số điện thoại là {row['phone']} \n", metadata={"type": "restaurant"}))

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings

splitter = RecursiveCharacterTextSplitter(chunk_size=5000, chunk_overlap=50)
split_docs = splitter.split_documents(doc)

embeddings = OpenAIEmbeddings()

# %%
from langchain.vectorstores import Qdrant
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

# Start Qdrant locally or use cloud, then connect
client = QdrantClient(host="localhost", port=6333)

# Create collection
client.recreate_collection(
    collection_name="hotels_and_ship_and_restaurants",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

# Index documents
vectorstore = Qdrant.from_documents(
    documents=split_docs,
    embedding=embeddings,
    location="http://localhost:6333",
    collection_name="hotels_and_ship_and_restaurants"
)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_29312\4072912840.py:9: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(

# %% [markdown]
# ### Reloading vector database

# %%
from langchain.vectorstores import Qdrant
from qdrant_client import QdrantClient
from langchain.embeddings import OpenAIEmbeddings

# Kết nối lại Qdrant
client = QdrantClient(host="localhost", port=6333)
embeddings = OpenAIEmbeddings()

# Load vectorstore từ collection đã tồn tại
vectorstore = Qdrant(
    client=client,
    collection_name="hotels_and_ship_and_restaurants",
    embeddings=embeddings
)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_29312\87818345.py:10: LangChainDeprecationWarning: The class `Qdrant` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-qdrant package and should be used instead. To use it run `pip install -U :class:`~langchain-qdrant` and import as `from :class:`~langchain_qdrant import Qdrant``.
#   vectorstore = Qdrant(

# %%
# Gọi truy vấn
results = vectorstore.similarity_search("Xây dựng một tour đi Tràng An và các điểm liên quan 2 ngày 1 đêm", k=10)

# %%
prompt_template = """
Bạn là một chuyên gia du lịch và có kiến thức đầy đủ về các khách sạn tại Việt Nam. Bạn hãy trả lời câu hỏi của tôi dựa trên thông tin mà tôi đã cung cấp cho bạn. Các câu hỏi chủ yếu về các địa điểm du lịch, và cách xây dựng tour du lịch hợp lí bao gồm khách sạn, nhà hàng cũng như các địa điểm du lịch nổi tiếng gần đó.
Dưới đây là thông tin về một khách sạn mà tôi đã tìm thấy: {results}

Câu hỏi của tôi là: {question}

Hãy cung cấp thông tin chi tiết về khách sạn và nhà hàng mà tôi yêu cầu, sử dụng các thông tin đã có và bổ sung thêm nếu có. Nếu có các thông tin về đường dẫn tới map hay facebook, website của khách sạn hay nhà hàng, hãy cung cấp cho tôi. Nếu không có thông tin nào, hãy nói là không có thông tin nào.
"""

# %%
messages = model.invoke(prompt_template.format(results=results, question="Sửa gợi ý bên trên, cho thông tin khách sạn lên trước tiên"))
print(messages.content)
# Out:
# **Khách sạn và Nhà hàng tại Ninh Bình:**
#
# 1. **Tam Coc Lion Kings Hotel & Resort**:
#    - **Địa chỉ**: Gần Tam Cốc, Ninh Bình.
#    - **Tiện ích**: Cung cấp xe đạp miễn phí, chỗ đậu xe riêng miễn phí, hồ bơi ngoài trời và khu vườn. Khách sạn còn gần các điểm tham quan như Đền Thung Nắng và Phim Trường Kong Skull Island.
#    - **Khoảng cách**: Cách Tam Cốc khoảng 1.9 km.
#    - **Dịch vụ**: Bữa sáng kiểu lục địa được phục vụ vào mỗi buổi sáng.
#    - **Ghi chú**: Khách sạn khá thuận tiện để tham quan các điểm du lịch nổi tiếng ở Ninh Bình.
#    - **Đường dẫn bản đồ**: Không có thông tin nào được cung cấp.
#
# 2. **Nhà hàng Lam Toi Restaurant**:
#    - **Địa chỉ**: Trang An Truong Yen, Ninh Bình.
#    - **Giờ mở cửa**: Mở cả ngày tới 10 PM.
#    - **Điện thoại**: 096 810 85 81.
#    - **Khoảng cách tới địa điểm gần nhất**: Cách 9.8 km (không đề cập cụ thể từ đâu).
#    - **Đường dẫn bản đồ**: [Bản đồ Lam Toi Restaurant](https://www.bing.com/maps?cp=20.27202033996582%7E105.91114807128906&lvl=17.0&q=Lam%20Toi%20Restaurant%2C%20Trang%20An%20Truong%20Yen%20430000).
#
# 3. **Nhà Hàng Ba Cửa**:
#    - **Địa chỉ**: Tràng An Truong Yen, Ninh Bình.
#    - **Điện thoại**: 091 631 16 58.
#    - **Khoảng cách tới địa điểm gần nhất**: Cách 9.8 km (không đề cập cụ thể từ đâu).
#    - **Đường dẫn bản đồ**: [Bản đồ Nhà Hàng Ba Cửa](https://www.bing.com/maps?cp=20.270193099975586%7E105.9135513305664&lvl=17.0&q=Nh%C3%A0%20H%C3%A0ng%20Ba%20C%E1%BB%ADa%2C%20Tr%C3%A0ng%20An%20Truong%20Yen%20430000).
#
# **Lưu ý**: Các thông tin về đường dẫn tới map của khách sạn hoặc nhà hàng được cung cấp nếu có sẵn trong dữ liệu ban đầu. Nếu bạn cần thêm thông tin chi tiết, bạn nên liên hệ trực tiếp với các đơn vị này.

# %%
messages.content
# Out:
# '**Khách sạn và Nhà hàng tại Ninh Bình:**\n\n1. **Tam Coc Lion Kings Hotel & Resort**:\n   - **Địa chỉ**: Gần Tam Cốc, Ninh Bình.\n   - **Tiện ích**: Cung cấp xe đạp miễn phí, chỗ đậu xe riêng miễn phí, hồ bơi ngoài trời và khu vườn. Khách sạn còn gần các điểm tham quan như Đền Thung Nắng và Phim Trường Kong Skull Island.\n   - **Khoảng cách**: Cách Tam Cốc khoảng 1.9 km. \n   - **Dịch vụ**: Bữa sáng kiểu lục địa được phục vụ vào mỗi buổi sáng.\n   - **Ghi chú**: Khách sạn khá thuận tiện để tham quan các điểm du lịch nổi tiếng ở Ninh Bình.\n   - **Đường dẫn bản đồ**: Không có thông tin nào được cung cấp.\n\n2. **Nhà hàng Lam Toi Restaurant**:\n   - **Địa chỉ**: Trang An Truong Yen, Ninh Bình.\n   - **Giờ mở cửa**: Mở cả ngày tới 10 PM.\n   - **Điện thoại**: 096 810 85 81.\n   - **Khoảng cách tới địa điểm gần nhất**: Cách 9.8 km (không đề cập cụ thể từ đâu).\n   - **Đường dẫn bản đồ**: [Bản đồ Lam Toi Restaurant](https://www.bing.com/maps?cp=20.27202033996582%7E105.91114807128906&lvl=17.0&q=Lam%20Toi%20Restaurant%2C%20Trang%20An%20Truong%20Yen%20430000).\n\n3. **Nhà Hàng Ba Cửa**:\n   - **Địa chỉ**: Tràng An Truong Yen, Ninh Bình.\n   - **Điện thoại**: 091 631 16 58.\n   - **Khoảng cách tới địa điểm gần nhất**: Cách 9.8 km (không đề cập cụ thể từ đâu).\n   - **Đường dẫn bản đồ**: [Bản đồ Nhà Hàng Ba Cửa](https://www.bing.com/maps?cp=20.270193099975586%7E105.9135513305664&lvl=17.0&q=Nh%C3%A0%20H%C3%A0ng%20Ba%20C%E1%BB%ADa%2C%20Tr%C3%A0ng%20An%20Truong%20Yen%20430000).\n\n**Lưu ý**: Các thông tin về đường dẫn tới map của khách sạn hoặc nhà hàng được cung cấp nếu có sẵn trong dữ liệu ban đầu. Nếu bạn cần thêm thông tin chi tiết, bạn nên liên hệ trực tiếp với các đơn vị này.'

# %%
from langchain_community.tools import TavilySearchResults

tavily_search = TavilySearchResults(max_results=3)
search_docs = tavily_search.invoke("Gợi ý tour du lịch Tràng An 2 ngày 1 đêm")

     # Format
formatted_search_docs = "\n\n---\n\n".join(
    [
        f'<Document href="{doc["url"]}">\n{doc["content"]}\n</Document>'
        for doc in search_docs
    ]
)
print(formatted_search_docs)
# Out:
# <Document href="https://thesinhtour.com/tour-tam-chuc-tam-coc-bai-dinh-trang-an-2-ngay-1-dem/?srsltid=AfmBOooA6_uIqyhgZjdLjJdMvhmkDOV4dYuaoONgS0wEZJaSkQyDjRzF">
# Hành trình Tam Chúc – Tam Cốc – Bái Đính – Tràng An 2 ngày 1 đêm sẽ đưa bạn đến với những danh thắng nổi tiếng bậc nhất miền Bắc. Tour kết hợp giữa tâm linh, danh thắng thiên nhiên và trải nghiệm du thuyền trên dòng nước xanh mát, chắc chắn sẽ mang đến cho bạn một chuyến đi đáng nhớ.
#
# LỊCH TRÌNH:
#
# NGÀY 01: HÀ NỘI- TAM CHÚC- TAM CỐC (ĂN TRƯA – TỐI)
#
# Buổi sáng: Tham quan chùa Tam Chúc [...] 14h00- 14h30: Sau khi dùng xong bữa trưa, Xe và hướng dẫn viên đưa quý khách đến thăm Tràng An. Với tuyến này quý khách có cơ hội tham quan 4 hang động tự nhiên trong số những hang động đẹp nhất trong khu du lịch Tràng An là Hang Lấm, Hang Vạng, Hang Thánh Trượt và hang cuối cùng là Hang Đại, quý khách còn dừng chân ghé thăm 3 điểm tâm linh là đền Cao Sơn, đền Suối Tiên và Hành Cung Vũ Lâm. [...] Tour Tam Chúc – Tam Cốc – Bái Đính – Tràng An 2 Ngày 1 Đêm
#
#
#
# Đặt Tour Ngay
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tour Tam Chúc – Tam Cốc – Bái Đính – Tràng An 2 Ngày 1 Đêm
#
# Thời gian: 2 ngày 1 đêm / Phương tiện: Ô tô / Khởi hành: hàng ngày
# </Document>
#
# ---
#
# <Document href="https://maichautourist.vn/package/tour-du-lich-ninh-binh-2-ngay-1-dem/">
# Tour du lịch Ninh Bình 2 ngày 1 đêm du ngoạn danh thắng Tràng An, tắm suối khoáng nóng Kênh Gà, khám phá rừng Cúc Phương hoang sơ. Giá rẻ chỉ từ 1890k.
# </Document>
#
# ---
#
# <Document href="https://eholiday.vn/tour-trang-an-bai-dinh-2-ngay-1-dem/">
# Tour Tràng An Bái Đính 2 ngày 1 đêm sẽ đưa quý khách đi du ngoạn những địa danh đẹp và nổi tiếng nhất tại Ninh Bình như: Chùa Bái Đính - ngôi chùa được mệnh
# </Document>
